# %%
a = 10
b = 5

# %%
a + b
# Out:
# 15

# %%
a - b
# Out:
# 5

# %%
a * b
# Out:
# 50

# %%
a / b
# Out:
# 2.0

# %%
# Floor Division
a // b
# Out:
# 2

# %%
# Modulus / Reminder
a % b
# Out:
# 0

# %%
a ** b
# Out:
# 100000

# %%
10 * 10 * 10 * 10 * 10
# Out:
# 100000

# %%
# BODMAS

print((4*5)-9+6/7)
# Out:
# 11.857142857142858

# %%
(4+(8**2)-3**2%3)
# Out:
# 68

# %%
9%1
# Out:
# 0

# %%
print(4 % (1 + 9)**2 - 60 // (7 + 2))
# Out:
# -2
