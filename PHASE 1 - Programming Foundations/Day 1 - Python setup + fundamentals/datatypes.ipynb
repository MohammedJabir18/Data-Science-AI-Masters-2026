# %% [markdown]
# #### Data types
#
# Data types are classifications that tell a computer what kind of value a variable holds and how to process it.

# %%
name = "Mike"

print(name)
# Out:
# Mike

# %%
name = input("Enter your name: ")

print("Welcome", name)
# Out:
# Welcome Mohammed Jabir

# %% [markdown]
# ##### Typecasting

# %%
var = 2

type(var)
# Out:
# int

# %%
print(float(var))
# Out:
# 2.0

# %%
var = 2.9
var_int = int(var)

print(var_int)
# Out:
# 2

# %%
var = 2

new_var = str(var)

# %%
new_var
# Out:
# '2'

# %%
type(new_var)
# Out:
# str

# %%
var_float = 3.4

new_var_float = str(var_float)

# %%
new_var_float
# Out:
# '3.4'

# %%
type(new_var_float)
# Out:
# str

# %%
int_var = "2.2"

# %%
new_int_var = int(int_var)

new_int_var
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 new_int_var = int(int_var)
#       2
#       3 new_int_var
#
# ValueError: invalid literal for int() with base 10: '2.2'

# %%
new_float = 3.9

int(new_float)
# Out:
# 3

# %%
string_var = "2.9"
float_var = float(string_var)
int_var = int(float_var)

# %%
int_var
# Out:
# 2

# %%
string_var = "3.1"
int_var = int(float(string_var))

int_var
# Out:
# 3

# %%
float("2.7")
# Out:
# 2.7

# %%
str(125)
# Out:
# '125'

# %%
# String to int for float number

string_var = "HELLO"

# %%
print(string_var[0])
# Out:
# H

# %%
print(string_var[-5])
# Out:
# H

# %%
string_var[0] = "M"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 string_var[0] = "M"
#
# TypeError: 'str' object does not support item assignment

# %%
var = "ABCDEFG"

# %%
print(var[2])
# Out:
# C
