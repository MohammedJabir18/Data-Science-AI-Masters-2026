# %% [markdown]
# #### Variables & Keywords
#
# * A Python variable is a reserved memory location to store values. In other words, a variable in a python program gives data to the computer for processing.
#
# * A keyword is a special, reserved word built into a programming language that has a fixed, predefined meaning.

# %%
a = ("Hello World")

# %%
print(a)
# Out:
# Hello World

# %%
type(a)
# Out:
# str

# %%
my_age = 25

# %%
print(my_age)
# Out:
# 25

# %%
score = 8.5

score
# Out:
# 8.5

# %%
var = "Hello world, I'm Mohammed Jabir"

# %%
type(var)
# Out:
# str

# %%
var = 10

# %%
type(var)
# Out:
# int

# %%
string_var = ("Hello world this is Mohammed Jabir")

# %%
print(string_var)
# Out:
# Hello world this is Mohammed Jabir

# %%
a = '10.5'

a
# Out:
# '10.5'

# %%
print(a)
type(a)
# Out:
# 10.5
# str

# %%
a = "True"
print(a)
type(a)
# Out:
# True
# str

# %%
a = True

print(a)
type(a)
# Out:
# True
# bool

# %%
5a = 67
# Out:
#   Cell In[28], line 1
#     5a = 67
#     ^
# SyntaxError: invalid decimal literal

# %%
a = 10
b = 20

# %%
print(a,"\n",b, sep="")
# Out:
# 10
# 20

# %%
float_var = 38.76

print(float_var)
type(float_var)
# Out:
# 38.76
# float

# %%
long_var = ("""This is India
I Love my country
All Indians are my 'brothers' and "sisters\"""")

print(long_var)
# Out:
# This is India
# I Love my country
# All Indians are my 'brothers' and "sisters"

# %%
type(long_var)
# Out:
# str

# %%
num1 = 30 
num2 = 20

res = num1 + num2

print(num1 - num2)
print(res)
# Out:
# 10
# 50

# %%
def func_sum(a, b):
    c = a + b

    return c

c = func_sum(5, 10)

print(c)

func_sum(9, 8)
# Out:
# 15
# 17

# %%
name = "Mohammed Jabir"
age = 25
score = 87.9
result = True

# %%
print(name, age, score, result, sep="\n")
# Out:
# Mohammed Jabir
# 25
# 87.9
# True
